# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('F:\insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
s=df['sex']
m=0;
f=0;
s[0]
for i in range(1338):
    if (s[i]=='female' ):
        f=f+1
        s[i]=1
    else:
        m=m+1
        s[i]=0
print(f)
print(m)
print(f+m)
s[0]
# Out:
# C:\Users\ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# 662
# 676
# 1338
# 1

# %%
df['sex']=s
df.head()
# Out:
#    age sex     bmi  children smoker     region      charges
# 0   19   1  27.900         0    yes  southwest  16884.92400
# 1   18   0  33.770         1     no  southeast   1725.55230
# 2   28   0  33.000         3     no  southeast   4449.46200
# 3   33   0  22.705         0     no  northwest  21984.47061
# 4   32   0  28.880         0     no  northwest   3866.85520

# %%
df['age'].median()
# Out:
# 39.0

# %%
df['age'].mean()
# Out:
# 39.20702541106129

# %%
df['smoker'].shape[0]
# Out:
# 1338

# %%
l=0
l1=0
for i in range(df['smoker'].shape[0]):
    if ( df['smoker'][i]=='yes'):
        df['smoker'][i]=1
        l=l+1
    else:
        l1=l1+1
        df['smoker'][i]=0
print(l)
print(l1)
print(l+l1)
# Out:
# C:\Users\ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# 274
# 1064
# 1338

# %%
df['age'].isnull().sum()
# Out:
# 0

# %%
df['sex'].isnull().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# 0    676
# 1    662
# Name: sex, dtype: int64

# %%
df.head(3)
# Out:
#    age sex    bmi  children smoker     region     charges
# 0   19   1  27.90         0      1  southwest  16884.9240
# 1   18   0  33.77         1      0  southeast   1725.5523
# 2   28   0  33.00         3      0  southeast   4449.4620

# %%
df['region'].shape[0]
# Out:
# 1338

# %%
for i in range(df['region'].shape[0]):
    if ( df['region'][i]=='southeast'):
        df['region'][i]=1
    elif ( df['region'][i]=='northwest'):
        df['region'][i]=2
    elif ( df['region'][i]=='southwest'):
        df['region'][i]=3
    elif ( df['region'][i]=='northeast'):
        df['region'][i]=4
df['region'].head()
# Out:
# C:\Users\ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# ...

# %%
df.head(2)
# Out:
#    age sex    bmi  children smoker region     charges
# 0   19   1  27.90         0      1      3  16884.9240
# 1   18   0  33.77         1      0      1   1725.5523

# %% [markdown]
# ## visulition

# %%
sns.relplot(x="age", y="bmi",hue="smoker", sizes=(95, 4000), data=df)

# %%
sns.relplot(x="charges", y="bmi", hue="smoker", data=df)

# %%
sns.pairplot(df, hue="smoker")
# Out:
# C:\Users\ravi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\ravi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
X=df[['age', 'bmi', 'children']]
y=df['charges']

# %%
from sklearn.model_selection import train_test_split
X_train, X_text, y_train, y_test =  train_test_split(X,y, test_size=0.8, random_state=100)

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()
lin.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin.intercept_
# Out:
# -4148.828672949694

# %%
lin.coef_
# Out:
# array([ 236.84776567,  244.84684027, -418.476311  ])

# %%
sns.countplot(x='sex', data=df)

# %%
sns.set_style("darkgrid")
sns.countplot(x='region', data=df, palette="BrBG")

# %%
sns.barplot(x='sex', y='bmi', data=df)

# %%
sns.catplot(x='region', y='bmi',hue='sex',kind="swarm", data=df)

# %%
sns.catplot(x='sex', y='bmi',kind="violin", data=df)

# %%
k=lin.predict(X_text)
plt.scatter(y_test,k)

# %%
X = df[['age', 'bmi', 'children']] 
y = df['charges']

# %%
plt.plot(X_train, model.predict(X_train), color='green')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=200)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.intercept_)
# Out:
# -6061.370503698072

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#           Coefficient
# age        245.607870
# bmi        289.753114
# children   573.600785

# %%
predictions = lm.predict(X_test)
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-e342737a68da> in <module>
# ----> 1 predictions = lm.predict(X_test)
#       2 print(predictions)
#
# NameError: name 'X_test' is not defined

# %%
plt.scatter(y_test,predictions)

# %%
print('asd')
# Out:
# asd
